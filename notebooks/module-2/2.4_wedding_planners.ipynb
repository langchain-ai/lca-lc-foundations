# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ## Setup Tools

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.
    You may need to make multiple queries to iteratively find the best options.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre"""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. Delegate tasks to your specialists for flights, venues and playlists.
    First find all the information you need to update the state. Once that is done you can delegate the tasks.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='34ef13cf-0c81-4b58-b3e3-3693a88d3b70'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 613, 'prompt_tokens': 293, 'total_tokens': 906, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cp24C35bR34iO49tfiKtaFFieFIBo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b3e6a-3c00-77d1-b868-6572618066d5-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'}, 'id': 'call_dkkgkYPwYCeOljbHU8DVyu51', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 613, 'total_tokens': 906, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='20339283-a992-46cb-a98e-d358ac0ae40e', tool_call_id='call_dkkgkYPwYCeOljbHU8DVyu51'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 318, 'prompt_tokens': 338, 'total_tokens': 656, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cp24HWRnhKa6NkgUXQsBTm343d0hJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b3e6a-510c-7093-b802-1b5ec1475dfb-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_khULySOI2cu7Ihj9lm4pKzBC', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_YKPaHLVMuZOmOViMl3EFAD84', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_ISGk29TLNaoKUKoytv627LC9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 338, 'output_tokens': 318, 'total_tokens': 656, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#               ToolMessage(content='Here are strong one-way flight options from London to Paris, based on price, shortest duration, and a sensible wedding-season date. Date-wise, early June is a great time for a Paris wedding (pleasant weather, lots of events, but still off-peak for travel).\n\nCheapest options (price-focused)\n- Route: LTN → CDG\n  - Times (local): 06:05 → 08:30 (Jun 01, 2026)\n  - Duration (per data): 1h25\n  - Cabin: Economy\n  - Price: 53 EUR\n  - Link: https://on.kiwi.com/cJFIpZ\n\n- Route: LTN → CDG\n  - Times (local): 19:40 → 22:00 (Jun 01, 2026)\n  - Duration: 1h20\n  - Cabin: Economy\n  - Price: 53 EUR\n  - Link: https://on.kiwi.com/sHJd3j\n\nNote: These are the lowest-priced options found (53 EUR) on the Jun 01, 2026 date.\n\nShortest-duration options (fastest direct flights)\n- Route: STN → CDG\n  - Times (local): 17:00 → 19:10 (May 15, 2026)\n  - Duration: 1h10\n  - Cabin: Economy\n  - Price: 64 EUR\n  - Link: https://on.kiwi.com/yQvEPa\n\n- Route: SEN → CDG\n  - Times (local): 11:20 → 13:30 (May 15, 2026)\n  - Duration: 1h10\n  - Cabin: Economy\n  - Price: 102 EUR\n  - Link: https://on.kiwi.com/jsLZ6p\n\n- Route: LGW → CDG\n  - Times (local): 16:30 → 18:50 (May 15, 2026)\n  - Duration: 1h10\n  - Cabin: Economy\n  - Price: 110 EUR\n  - Link: https://on.kiwi.com/1gMbZF\n\n- Route: LGW → CDG\n  - Times (local): 18:00 → 20:20 (May 15, 2026)\n  - Duration: 1h10\n  - Cabin: Economy\n  - Price: 110 EUR\n  - Link: https://on.kiwi.com/Qcafas\n\n- Route: LGW → CDG\n  - Times (local): 19:00 → 21:20 (May 15, 2026)\n  - Duration: 1h10\n  - Cabin: Economy\n  - Price: 110 EUR\n  - Link: https://on.kiwi.com/U5xGRU\n\nNote: These are the fastest direct options (duration around 1h10). Local times are shown as listed; durations come from durationInSeconds data.\n\nOther notable options (good value or convenient timing)\n- Date: Jun 01, 2026\n  - STN → CDG\n  - Times (local): 14:35 → 17:45\n  - Duration: 1h10\n  - Price: 55 EUR\n  - Link: https://on.kiwi.com/Hjlh9W\n\n- Date: Jun 01, 2026\n  - STN → CDG\n  - Times (local): 15:35 → 17:45\n  - Duration: 1h10\n  - Price: 55 EUR\n  - Link: https://on.kiwi.com/Hjlh9W\n\n- Date: May 15, 2026\n  - LHR → CDG\n  - Times (local): 07:40 → 14:00\n  - Duration: 6h20 (via AMS)\n  - Price: 121 EUR\n  - Link: https://on.kiwi.com/2C475z\n\nSeasonal recommendation\n- Best time for a wedding trip to Paris: Early June (mid-late May also good). Pleasant weather, long daylight hours, and typically reliable travel conditions.\n\nSummary and recommendation\n- Best price pick: 53 EUR options from LTN to CDG on 01/06/2026. If minimizing cost is the top priority, these are the standout choices.\n- Shortest flight pick: Direct flights around 1h10 (e.g., STN→CDG on May 15, 2026, 17:00–19:10 local). Great for minimizing travel time.\n- My overall recommendation: If you want a balance of price and convenience for a wedding trip, consider the 53 EUR LTN→CDG options on 01/06/2026 for cost savings, with a morning or evening departure depending on your wedding schedule. If you need a slightly quicker option on a nearby date, the 55–64 EUR direct options on May 15 or June 1 are solid alternatives.\n\nHave a wonderful trip planning your wedding in Paris! Fun fact: Paris is nicknamed La Ville Lumière (The City of Light) and is home to the Louvre, the world’s largest art museum. That makes it a magical backdrop for a wedding memory.', name='search_flights', id='1522da45-6ac6-4ecf-8b00-686bdb4a3846', tool_call_id='call_khULySOI2cu7Ihj9lm4pKzBC'),
#               ToolMessage(content='Here are Paris wedding venues that can accommodate around 100 guests, ordered by likely price tier (lowest to highest) and with exact or near-exact 100-capacity details where available:\n\n- Les 3 Salons (Saint-Germain-des-Prés, Paris)\n  - Capacity: up to 100 guests\n  - Vibe: Historic, intimate, three connected vaulted rooms\n  - Why consider: Usually more budget-friendly than major luxury hotels; central city location; flexible modular spaces\n  - Notes: Private settings with in-house services; strong reviews for intimate Paris weddings\n\n- The Peninsula Paris (8th arrondissement)\n  - Capacity: up to 100 guests for a sit-down dinner\n  - Vibe: Iconic luxury hotel with elegant ballrooms and refined service\n  - Why consider: Trusted luxury brand, impeccable service, picturesque venues for photos\n  - Notes: Premium pricing, but excellent guest experience and reliability\n\n- Four Seasons Hotel George V, Paris (8th arrondissement)\n  - Capacity: up to 100 guests for receptions\n  - Vibe: Ultra-luxury, grand salon spaces, exceptional cuisine and service\n  - Why consider: Renowned for seamless large-scale events; multiple salon options that can be privatized\n  - Notes: Highest price tier among these options, but top-tier experience and reviews\n\nIf you’d like, I can pull current availability and provide ballpark price ranges or quotes for specific dates and package options for these venues.', name='search_venues', id='dcaa139c-0aeb-4400-8885-9768d50495f2', tool_call_id='call_YKPaHLVMuZOmOViMl3EFAD84'),
#               ToolMessage(content="Here’s a curated Jazz-themed wedding playlist pulled from the jazz tracks dataset. It mixes bossa nova, classic swing, and cool jazz to suit a classy wedding vibe. I’ve included duration and price for each track.\n\n1) Outra Vez — Antônio Carlos Jobim — 2:06.51 — $0.99\n2) Fotografia — Antônio Carlos Jobim — 2:09.23 — $0.99\n3) Lament — Miles Davis — 2:14.19 — $0.99\n4) Se Todos Fossem Iguais A Você (Instrumental) — Antônio Carlos Jobim — 2:14.95 — $0.99\n5) Samba De Uma Nota Só (One Note Samba) — Antônio Carlos Jobim — 2:17.27 — $0.99\n6) The Meaning Of The Blues — Miles Davis — 2:48.59 — $0.99\n7) Generique — Miles Davis — 2:48.78 — $0.99\n8) Desafinado — Antônio Carlos Jobim — 3:05.34 — $0.99\n9) Jeepers Creepers — Gene Krupa — 3:05.97 — $0.99\n10) Let Me Off Uptown — Gene Krupa — 3:07.64 — $0.99\n11) Opus No.1 — Gene Krupa — 2:59.80 — $0.99\n12) Leave Us Leap — Gene Krupa — 3:02.73 — $0.99\n13) Now's The Time — Miles Davis — 3:17.46 — $0.99\n14) Jeru — Miles Davis — 3:13.41 — $0.99\n15) Drum Boogie — Gene Krupa — 3:11.56 — $0.99\n16) I Don't Wanna Be Kissed (By Anyone But You) — Miles Davis — 3:11.32 — $0.99\n17) Payin' Them Dues Blues — Gene Krupa — 3:18.56 — $0.99\n18) Jungle Drums — Gene Krupa — 3:19.63 — $0.99\n\nTotal duration: 3,092.91 seconds ≈ 51 minutes 32.91 seconds (about 51:33)\nTotal cost: 18 tracks × $0.99 = $17.82\n\nNotes and options:\n- If you want a lighter ambiance for cocktails or dining, I can swap in softer Jobim ballads or Miles ballads.\n- If you want more dancing-friendly tracks later in the evening, I can add a few upbeat swing or vocal jazz standards.\n- I can also tailor the mix to ceremony, cocktail hour, or reception specifically.\n\nWould you like me to adjust the vibe (more romantic, more upbeat, or more modern jazz) or add/remove tracks for a longer/shorter playlist?", name='suggest_playlist', id='172c7296-a3a5-4b1c-8e6b-98291ac13e81', tool_call_id='call_ISGk29TLNaoKUKoytv627LC9'),
#               AIMessage(content='Fantastic news. I’ve got your basics set and I’ve run initial checks with our specialists. Here’s the plan and the options I’m coordinating for a 100-guest jazz-themed wedding in Paris, with you in London.\n\nWhat we’ve confirmed\n- Origin: London\n- Destination: Paris\n- Guest count: 100\n- Genre vibe: Jazz (classic to modern jazz with some Bossa Nova touches for ambiance)\n\nFlight options (Travel Specialist)\n- Top balance picks for a June wedding window (early June is a sweet spot for weather and events in Paris):\n  - Option A: Luton (LTN) to Paris CDG\n    - 06:05–08:30, 1h25\n    - Price: ~53 EUR\n    - Jun 1, 2026\n  - Option B: Stansted (STN) to Paris CDG\n    - 17:00–19:10, 1h10\n    - Price: ~64 EUR\n    - May 15, 2026\n  - Option C: Gatwick (LGW) to Paris CDG\n    - 16:30–18:50, 1h10\n    - Price: ~110 EUR\n    - May 15, 2026\n- Recommendation: If you want the best value with a reasonable flight time, consider the LTN–CDG options on Jun 1, 2026. If you’d rather minimize travel time for key guests, the direct STN/ LGW options around mid-May or early June are solid.\n\nNext steps for flights\n- I’ll coordinate a group-booking block for 100 guests, confirm exact travel dates (arrival in Paris before the wedding and a coordinated group departure), and secure preferred cabins.\n- I’ll also arrange group transfers from CDG to the venue and back.\n- Please share preferred travel dates (arrival window in Paris, wedding date) and any airline or seating preferences, plus if you want a couple of backup dates.\n\nVenues (Venue Specialist)\nShortlist for around 100 guests, with vibe and suitability:\n- Les 3 Salons (Saint-Germain-des-Prés)\n  - Capacity: up to ~100\n  - Vibe: Historic, intimate, modular spaces\n  - Pros: More budget-friendly than top luxury hotels; central; flexible in-house services\n  - Cons: Smaller scale may require careful floor plan for a 100p setting\n- The Peninsula Paris (8th arrondissement)\n  - Capacity: up to 100 for sit-down dinner\n  - Vibe: Iconic luxury with elegant ballrooms\n  - Pros: Renowned service, stunning photos, strong culinary offerings\n  - Cons: Premium pricing\n- Four Seasons Hotel George V (8th arrondissement)\n  - Capacity: up to 100 for receptions\n  - Vibe: Ultra-luxury, grand spaces, exceptional service\n  - Pros: Seamless large-scale events, multiple private spaces\n  - Cons: Highest price tier of the three\n\nWhat I’ll do next:\n- Check current availability for your exact date window with each venue.\n- Prepare ballpark price ranges and sample package options (catering, room blocks, décor, AV, private room options).\n- If you have a preferred date range (e.g., early June 2026) and non-negotiables (ceremony vs. reception-only, private dining, outdoor options), tell me and I’ll tailor the proposals.\n\nPlaylists (Playlist Specialist)\nCurrent Jazz-themed playlist includes a mix of bossa nova, swing, and cool jazz, suitable for ceremony, cocktail, dinner, and dancing. Highlights:\n- Antonio Carlos Jobim, Miles Davis, Gene Krupa tracks\n- Total duration of curated list: ~51 minutes (with room to extend)\n- Pricing: $0.99 per track (license-friendly)\n\nProposed playlist structure:\n- Ceremony (soft, romantic): 6–8 tracks (bossa nova and gentle jazz standards)\n- Cocktail hour (cool/warm jazz): 8–12 tracks (lighter, classy vibes)\n- Dinner (instrumental/classic jazz standards): 12–18 tracks\n- Dancing (upbeat swing/jazz standards): 20–30 tracks\n\nWhat I’ll do next:\n- Build a ceremony-specific sub-list and a longer reception/dancing list, tuned to your preferred tempo (romantic, upbeat, or modern-jazz blend).\n- Confirm licensing and streaming options, plus whether you want live jazz piano/sax as an alternative.\n- If you’d like, I can craft a complete 2–3 hour version of the playlist and a separate 1–hour “cocktail” version.\n\nQuestions to finalize the plan\n- Date window: Do you have a firm wedding date in mind, or should I target a 1–2 week wi ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic news. I’ve got your basics set and I’ve run initial checks with our specialists. Here’s the plan and the options I’m coordinating for a 100-guest jazz-themed wedding in Paris, with you in London.
#
# What we’ve confirmed
# - Origin: London
# - Destination: Paris
# - Guest count: 100
# - Genre vibe: Jazz (classic to modern jazz with some Bossa Nova touches for ambiance)
#
# Flight options (Travel Specialist)
# - Top balance picks for a June wedding window (early June is a sweet spot for weather and events in Paris):
#   - Option A: Luton (LTN) to Paris CDG
#     - 06:05–08:30, 1h25
#     - Price: ~53 EUR
#     - Jun 1, 2026
#   - Option B: Stansted (STN) to Paris CDG
#     - 17:00–19:10, 1h10
#     - Price: ~64 EUR
#     - May 15, 2026
#   - Option C: Gatwick (LGW) to Paris CDG
#     - 16:30–18:50, 1h10
#     - Price: ~110 EUR
#     - May 15, 2026
# - Recommendation: If you want the best value with a reasonable flight time, consider the LTN–CDG options on Jun 1, 2026. If you’d rather minimize travel time for key guests, the direct STN/ LGW options around mid-May or early June are solid.
#
# Next steps for flights
# - I’ll coordinate a group-booking block for 100 guests, confirm exact travel dates (arrival in Paris before the wedding and a coordinated group departure), and secure preferred cabins.
# - I’ll also arrange group transfers from CDG to the venue and back.
# - Please share preferred travel dates (arrival window in Paris, wedding date) and any airline or seating preferences, plus if you want a couple of backup dates.
#
# Venues (Venue Specialist)
# Shortlist for around 100 guests, with vibe and suitability:
# - Les 3 Salons (Saint-Germain-des-Prés)
#   - Capacity: up to ~100
#   - Vibe: Historic, intimate, modular spaces
#   - Pros: More budget-friendly than top luxury hotels; central; flexible in-house services
#   - Cons: Smaller scale may require careful floor plan for a 100p setting
# - The Peninsula Paris (8th arrondissement)
#   - Capacity: up to 100 for sit-down dinner
#   - Vibe: Iconic luxury with elegant ballrooms
#   - Pros: Renowned service, stunning photos, strong culinary offerings
#   - Cons: Premium pricing
# - Four Seasons Hotel George V (8th arrondissement)
#   - Capacity: up to 100 for receptions
#   - Vibe: Ultra-luxury, grand spaces, exceptional service
#   - Pros: Seamless large-scale events, multiple private spaces
#   - Cons: Highest price tier of the three
#
# What I’ll do next:
# - Check current availability for your exact date window with each venue.
# - Prepare ballpark price ranges and sample package options (catering, room blocks, décor, AV, private room options).
# - If you have a preferred date range (e.g., early June 2026) and non-negotiables (ceremony vs. reception-only, private dining, outdoor options), tell me and I’ll tailor the proposals.
#
# Playlists (Playlist Specialist)
# Current Jazz-themed playlist includes a mix of bossa nova, swing, and cool jazz, suitable for ceremony, cocktail, dinner, and dancing. Highlights:
# - Antonio Carlos Jobim, Miles Davis, Gene Krupa tracks
# - Total duration of curated list: ~51 minutes (with room to extend)
# - Pricing: $0.99 per track (license-friendly)
#
# Proposed playlist structure:
# - Ceremony (soft, romantic): 6–8 tracks (bossa nova and gentle jazz standards)
# - Cocktail hour (cool/warm jazz): 8–12 tracks (lighter, classy vibes)
# - Dinner (instrumental/classic jazz standards): 12–18 tracks
# - Dancing (upbeat swing/jazz standards): 20–30 tracks
#
# What I’ll do next:
# - Build a ceremony-specific sub-list and a longer reception/dancing list, tuned to your preferred tempo (romantic, upbeat, or modern-jazz blend).
# - Confirm licensing and streaming options, plus whether you want live jazz piano/sax as an alternative.
# - If you’d like, I can craft a complete 2–3 hour version of the playlist and a separate 1–hour “cocktail” version.
#
# Questions to finalize the plan
# - Date window: Do you have a firm wedding date in mind, or should I target a 1–2 week window in early June 2026 and propose exact dates to the venues?
# - Venue preferences: Which of the three venues resonates most (Les 3 Salons for intimate charm, Peninsula for luxury, George V for grandeur)? Any must-haves (private terrace, courtyard, specific catering style, in-house décor)?
# - Budget range: Rough totals for venue, flights, and catering? This helps me tailor packages and negotiate effectively.
# - Schedule outline: Do you want a ceremony on-site at the venue, or a separate ceremony location in Paris with a reception at the chosen venue?
# - Playlist specifics: Any must-play songs, first dance style, or artists you want featured or avoided? Any live music preference (piano/sax) in addition to the DJ/playlist format?
# - Guest experience: Any special needs (dietary restrictions, accessibility, accommodation for international guests, group transfers, or welcome bags)?
#
# How I’ll coordinate moving forward
# - Flight Specialist: secure a group booking block for 100 guests and arrange CDG transfers to the venue; confirm arrival/departure windows and backup dates.
# - Venue Specialist: check availability and pricing for the top 3 venues, with preferred date windows, and prepare formal proposals with inclusions (catering, décor, AV, private spaces).
# - Playlist Specialist: finalize a ceremony-to-reception playlist tailored to your flow and length, confirm licensing, and provide a ready-to-run track list for ceremony, cocktails, dinner, and dancing.
#
# Would you like me to proceed with availability checks and quotes for those three venues and to lock in a provisional flight block for the early June window? If yes, tell me your preferred date range and any must-haves, and I’ll move to the next round of confirmations.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
