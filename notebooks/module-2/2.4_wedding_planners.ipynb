# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Setup Tools

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain_mcp_adapters.tools import load_mcp_tools

class MCPService:
    def __init__(self, config: dict):
        # transport "http" is the 2025 standard for remote servers
        self.client = MultiServerMCPClient(config)
        self.tools = []

    async def get_tools(self):
        # In 2025, fetch tools from the client directly
        # Ensure your client stays 'entered' via a context manager in the main loop
        self.tools = await self.client.get_tools()
        return self.tools

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
# 1. Define the function
def initialize_travel_agent(tools):
    return create_agent(
        model="gpt-5-nano",
        tools=tools,
        system_prompt="""
        You are a travel agent. Search for flights to the desired destination wedding location.
        You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
        - Price (lowest, economy class)
        - Duration (shortest)
        - Date (time of year which you believe is best for a wedding at this location)
        To make things easy, only look for one ticket, one way.
        You may need to make multiple searches to iteratively find the best options.
        You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
        Once you have found the best options, let the user know your shortlist of options."""
    )

# %%
from langchain.agents import create_agent

# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.
    You may need to make multiple queries to iteratively find the best options.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from typing import Annotated
from langchain_core.tools import tool, InjectedToolCallId
from langchain_core.messages import HumanMessage, ToolMessage
from langgraph.types import Command  # <--- FIX: Add this line
from langgraph.prebuilt import InjectedState

@tool
async def search_flights(origin: str, destination: str) -> str:
    """
    Travel agent searches for flights to the desired destination wedding location.
    Args:
        origin: The city the guests are departing from (e.g., 'London')
        destination: The wedding destination city (e.g., 'Paris')
    """
    print(f"DEBUG: Searching flights from {origin} to {destination}...")
    # Simply call the sub-agent with the strings provided by the coordinator
    response = await travel_agent.ainvoke({
        "messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]
    })
    
    print(f"DEBUG: Search complete. Found {len(response['messages'])} messages.")
    # Return the content of the last message
    return response['messages'][-1].content
    
@tool
def search_venues(destination: str, guest_count: int) -> str:
    """
    Search for wedding venues based on location and capacity.
    Args:
        destination: The city/location for the wedding.
        guest_count: The total number of guests.
    """
    # No more runtime.state lookup needed!
    query = f"Find wedding venues in {destination} for {guest_count} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(genre: str) -> str:
    """
    Playlist agent curates the perfect playlist for the given genre.
    Args:
        genre: The musical genre (e.g., 'jazz', 'rock').
    """
    # No more runtime.state lookup
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(
    origin: str, 
    destination: str, 
    guest_count: int, 
    genre: str, 
    # This ID is automatically stripped from the LLM's view and injected by the runtime
    tool_call_id: Annotated[str, InjectedToolCallId] 
) -> Command:
    """Update the wedding plan state when all details (origin, destination, guest count, genre) are known."""
    return Command(
        update={
            "origin": origin,
            "destination": destination,
            "guest_count": guest_count,
            "genre": genre,
            # tool_call_id is required to link this message back to the LLM's request
            "messages": [ToolMessage("Wedding state successfully updated.", tool_call_id=tool_call_id)]
        }
    )

# %%
async def run_wedding_orchestrator(user_input):
    global travel_agent
    config = {"travel_server": {"transport": "http", "url": "https://mcp.kiwi.com"}}
    # 1. Initialize client normally (NO 'async with')
    client = MultiServerMCPClient(config)
    
    # 2. Fetch tools directly
    mcp_tools = await client.get_tools()
    
    # 3. Initialize agents as before
    travel_agent = initialize_travel_agent(mcp_tools)
        
    # Now, tools like search_flights will have an active connection
    coordinator = create_agent(
        model="gpt-5-nano",
        tools=[search_flights, search_venues, suggest_playlist, update_state],
        state_schema=WeddingState,
        system_prompt="""
    You are a wedding coordinator. 
    1. Immediately call 'search_flights' and 'search_venues'. 
    2. Do not plan anything until you have results from these tools.
    3. First find all the information you need to update the state. Once that is done you can delegate the tasks.
    4. Once you have received their answers, coordinate the perfect wedding for me.
    """
    )

     # 4. Invoke the agent. It will now handle HTTP requests per tool call.
    return await coordinator.ainvoke({"messages": [HumanMessage(content=user_input)]})

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await run_wedding_orchestrator(
    "I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre"
)

# async for chunk in coordinator.astream(
#     {"messages": [HumanMessage(content="Your request here")]},
#     stream_mode="updates"
# ):
#     for node_name, state_update in chunk.items():
#         print(f"--- Node: {node_name} ---")
#         if "messages" in state_update:
#             print(state_update["messages"][-1].content)
# Out:
# DEBUG: Searching flights from London to Paris...
# DEBUG: Search complete. Found 7 messages.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': 100,
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='feb313a8-6233-4b8d-a0f5-e6bae933c424'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 416, 'total_tokens': 928, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsIQZjrbshwg1TW5gmUrWlpgidfUo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6cc7-ab43-7053-980a-0d57f25eaf0a-0', tool_calls=[{'name': 'search_flights', 'args': {'origin': 'London', 'destination': 'Paris'}, 'id': 'call_JUTWjKph5xnNl3y711Lrz3Q2', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {'destination': 'Paris', 'guest_count': 100}, 'id': 'call_4phgYg406ZvtoFCEuAuuDuFg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 416, 'output_tokens': 512, 'total_tokens': 928, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content='Here are the best one-way London to Paris flight options I found. I’ve focused on the cheapest fares, the shortest durations, and dates that fit a wedding trip nicely (late spring to early summer or early autumn).\n\nCheapest options (price prioritized)\n- Option A\n  - Route: London Southend (SEN) → Paris CDG\n  - When: 18 Oct 2026\n  - Price: €29\n  - Duration: about 1h 10m\n  - Times (local): Dep 08:25 → Arr 09:35\n  - Booking: https://on.kiwi.com/k6bjBp\n\n- Option B\n  - Route: London Southend (SEN) → Paris CDG\n  - When: 15 Oct 2026\n  - Price: €33\n  - Duration: about 1h 50m\n  - Booking: https://on.kiwi.com/UN0CmC\n\n- Option C\n  - Route: London Southend (SEN) → Paris CDG\n  - When: 3 Sep 2026\n  - Price: €34\n  - Duration: about 1h 40m\n  - Booking: https://on.kiwi.com/3NPX7y\n\n- Option D\n  - Route: London Southend (SEN) → Paris CDG\n  - When: 30 Aug 2026\n  - Price: €38\n  - Duration: about 1h 10m\n  - Booking: https://on.kiwi.com/DRWjXU\n\nShortest-duration options (duration prioritized)\n- Option X\n  - Route: London Luton (LTN) → Paris CDG\n  - When: 1 Jun 2026\n  - Price: €49\n  - Duration: about 1h 20m\n  - Booking: https://on.kiwi.com/71JNea\n\n- Option Y\n  - Route: London Luton (LTN) → Paris CDG\n  - When: 2 Jun 2026\n  - Price: €49\n  - Duration: about 1h 20m\n  - Booking: https://on.kiwi.com/IzD1TP\n\nWedding-friendly timing advice (best time of year)\n- For Paris, late spring and early autumn are ideal: May–June or September.\n- If you want the very best balance of price and pleasant weather, consider June 1st–June 3rd, 2026 or early September 2026 windows. The June options above are among the cheapest still quite reasonable in duration.\n\nRecommendation\n- Top pick for a wedding trip: Option B or Option A around early June. They offer very low fares (around €33–€49) with short flight times, helping you minimize travel stress before a wedding. If you’re flexible on airport, the LTN/SEN options can be even cheaper than typical LHR/LGW fares.\n\nHave a fantastic trip to Paris, and congrats on the wedding! Fun fact: Paris is nicknamed the City of Light—believed to originate from the city’s early role during the Age of Enlightenment and the overlay of culture and illumination that makes it so magical at night.', name='search_flights', id='a397befb-9bef-4f10-b4b3-841324490f49', tool_call_id='call_JUTWjKph5xnNl3y711Lrz3Q2'),
#               ToolMessage(content='Here are Paris wedding venues that have an exact capacity around 100 guests (capacity matches 100 in various seating/cocktail configurations). I’ve ranked them roughly from lower to higher price tier, and noted the capacity arrangement and a quick perk for each.\n\n- Le Cabanon (Paris 9e)\n  - Capacity: Privatisation up to 100 people (exact match for a wedding reception)\n  - Price tier: Budget-friendly to Mid-range (private venue/bar style)\n  - Why consider: intimate, friendly Paris venue with private-event privacy\n  - Source: https://lecabanon.paris/ (privatisation up to 100)\n\n- Centre Monceau (Paris 8e)\n  - Capacity: 100 people (141–175 m² total space; versatile for cocktails or seated events)\n  - Price tier: Mid-range (location and space typical for private events in central Paris)\n  - Why consider: well-located private space with established event setups\n  - Source: ABC Salles listing: 145 m² – 100 personnes; https://www.abcsalles.com/lieu/centre-monceau\n\n- Morning Monceau (Paris 8e)\n  - Capacity: 100 people\n  - Price tier: Mid-range\n  - Why consider: private event-friendly venue with a rooftop option and flexible layout\n  - Source: Privateaser listing: Morning Monceau – Morning Coffee et rooftop; https://www.privateaser.com/lieu/52185-centre-monceau-paris (note: Center Monceau listing also appears here)\n\n- Café de l’Homme (Paris 16e)\n  - Capacity: Cocktail up to 100 people; seated ~70\n  - Price tier: Mid-to-high\n  - Why consider: iconic Paris venue with stunning views of the Eiffel Tower; strong private-event pedigree\n  - Source: Café de l’Homme site: https://cafedelhomme.com/privatiser/mariage-tour-eiffel-paris\n\n- Hotel Marignan Champs-Élysées (Paris 8e)\n  - Capacity: Up to 100 guests for cocktails; 80 seated\n  - Price tier: Luxury\n  - Why consider: chic, centrally located, renowned service; elegant private spaces for a stylish wedding\n  - Source: Hotel Marignan page: https://www.hotelmarignanelyseesparis.com/en/pagex/wedding-venues-paris-france.285.html\n\n- The Peninsula Paris (1er/Champs-Élysées area)\n  - Capacity: Ballrooms can host up to 100 for a sit-down dinner\n  - Price tier: Luxury to Ultra-luxury\n  - Why consider: world-class service, multiple luxe spaces, and privacy for weddings\n  - Source: Peninsula Paris wedding venues page: https://www.peninsula.com/en/paris/events/hotel-wedding-venues\n\nNotes\n- All listed options have a capacity exactly 100 in some setup (cocktail, seated dinner, or privatised event) suitable for a wedding of 100 guests.\n- Price information for private events is not always published publicly; quotes are typically provided on request. The entries above are grouped by general price tier (Budget to Luxury) based on typical market positioning and publicly available descriptions.\n- If you’d like, I can proceed to obtain quotes and check real-time availability for any of these venues.', name='search_venues', id='20a2b30e-1710-4144-870d-4b5276375a86', tool_call_id='call_4phgYg406ZvtoFCEuAuuDuFg'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 677, 'prompt_tokens': 2022, 'total_tokens': 2699, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsIVzaioGumsGhwdf1i6yOPxW9qiG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6ccc-c8fd-73e2-8e28-f975d505cfc8-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': 100, 'genre': 'jazz'}, 'id': 'call_BVTRIwiq9NvK3XgDzFFj5cX5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2022, 'output_tokens': 677, 'total_tokens': 2699, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='Wedding state successfully updated.', name='update_state', id='a25e76ae-7fe0-4bbe-94de-a5fe3cb726e7', tool_call_id='call_BVTRIwiq9NvK3XgDzFFj5cX5'),
#               AIMessage(content='Fantastic! I’ve started lining up core pieces for a Paris wedding for 100 guests with a jazz vibe. Here’s what I found so far and the next steps to tighten things up.\n\nWhat I found for you\n\nFlight options (London → Paris)\n- Cheapest options (price-focused)\n  - Option A: SEN → CDG\n    - When: 18 Oct 2026\n    - Price: €29\n    - Duration: ~1h10m\n  - Option B: SEN → CDG\n    - When: 15 Oct 2026\n    - Price: €33\n    - Duration: ~1h50m\n- Shortest durations (time-focused)\n  - Option X: Luton → CDG\n    - When: 1 Jun 2026\n    - Price: €49\n    - Duration: ~1h20m\n  - Option Y: Luton → CDG\n    - When: 2 Jun 2026\n    - Price: €49\n    - Duration: ~1h20m\n\nNotes\n- The results show dates in 2026 and include multiple London-area airports (SEN, LTN). If you have a preferred travel window (e.g., early June 2026 for nicer weather and reasonable fares), I can refine to that window and check availability for your group.\n\nWedding venues in Paris (capacity ~100)\n- Le Cabanon (Paris 9e)\n  - Capacity: Private privatization up to 100\n  - Tier: Budget to Mid-range\n  - Perk: Intimate, private-event vibe\n- Centre Monceau (Paris 8e)\n  - Capacity: 100 (private space, cocktails or seated)\n  - Tier: Mid-range\n  - Perk: Central, established private-event setups\n- Morning Monceau (Paris 8e)\n  - Capacity: 100\n  - Tier: Mid-range\n  - Perk: Private event-friendly, rooftop option\n- Café de l’Homme (Paris 16e)\n  - Capacity: Cocktail up to 100; seated ~70\n  - Tier: Mid-to-high\n  - Perk: Iconic Eiffel Tower views\n- Hotel Marignan Champs-Élysées (Paris 8e)\n  - Capacity: Up to 100 for cocktails; 80 seated\n  - Tier: Luxury\n  - Perk: Chic, high-end service, central location\n- The Peninsula Paris (1er/Champs-Élysées)\n  - Capacity: Ballrooms up to 100 for sit-down dinners\n  - Tier: Luxury to Ultra-luxury\n  - Perk: World-class service, multiple luxe spaces, privacy\n\nNotes\n- All listed options can host ~100 guests in various setups (cocktail, seated, or privatised events).\n- Public price details aren’t always published; quotes are typically provided on request. I can handle the quote requests and availability checks for you.\n\nWhat I need from you to move forward (quick)\n- Date window/year you’re targeting (e.g., early June 2026 or early September 2026, or another window).\n- Budget range for the venue (ballpark per venue or total for venue + catering).\n- Preferred vibe/style: historic/chic, modern, iconic views, intimate/private, etc.\n- Do you want a ceremony included at the same site, or just a reception?\n- Catering style preference (in-house venue catering vs. external caterer) and any dietary needs.\n- Music plan: live jazz ensemble vs. DJ with jazz-influenced sets? Any must-have repertoires (e.g., standards, swing, modern jazz)?\n- Guest lodging: do you want me to suggest a small set of hotels near the venues, with group rates?\n- Transportation needs: private transfers from airport/hotel to venue?\n\nNext steps I can take once you confirm\n- Shortlist 3–5 top venues (based on vibe and price tier) and start requesting current availability and formal quotes for your target date.\n- Propose 1–2 live jazz acts or a DJ package with a jazz-forward set, and draft a provisional music plan (cocktail jazz, dinner background, party set).\n- Compile a preliminary wedding day timeline (ceremony, cocktail hour, reception, dinner, dancing) and recommended room layouts for each venue.\n- Suggest nearby hotels for guest blocks and outline group-rate options.\n- Create a clear budget breakdown (venue, catering, entertainment, decor, transport, accommodations) and a tentative timeline.\n\nWould you like me to:\n1) Focus on a date window (e.g., early June 2026) and start checking availability/quotes for 3–4 top venues (Le Cabanon, Centre Monceau, Café de l’Homme, Hotel Marignan, Peninsula) and 1–2 live jazz options?\n2) Or, share your preferred date/year and budget first, and I’ll tailor the shortlist ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic! I’ve started lining up core pieces for a Paris wedding for 100 guests with a jazz vibe. Here’s what I found so far and the next steps to tighten things up.
#
# What I found for you
#
# Flight options (London → Paris)
# - Cheapest options (price-focused)
#   - Option A: SEN → CDG
#     - When: 18 Oct 2026
#     - Price: €29
#     - Duration: ~1h10m
#   - Option B: SEN → CDG
#     - When: 15 Oct 2026
#     - Price: €33
#     - Duration: ~1h50m
# - Shortest durations (time-focused)
#   - Option X: Luton → CDG
#     - When: 1 Jun 2026
#     - Price: €49
#     - Duration: ~1h20m
#   - Option Y: Luton → CDG
#     - When: 2 Jun 2026
#     - Price: €49
#     - Duration: ~1h20m
#
# Notes
# - The results show dates in 2026 and include multiple London-area airports (SEN, LTN). If you have a preferred travel window (e.g., early June 2026 for nicer weather and reasonable fares), I can refine to that window and check availability for your group.
#
# Wedding venues in Paris (capacity ~100)
# - Le Cabanon (Paris 9e)
#   - Capacity: Private privatization up to 100
#   - Tier: Budget to Mid-range
#   - Perk: Intimate, private-event vibe
# - Centre Monceau (Paris 8e)
#   - Capacity: 100 (private space, cocktails or seated)
#   - Tier: Mid-range
#   - Perk: Central, established private-event setups
# - Morning Monceau (Paris 8e)
#   - Capacity: 100
#   - Tier: Mid-range
#   - Perk: Private event-friendly, rooftop option
# - Café de l’Homme (Paris 16e)
#   - Capacity: Cocktail up to 100; seated ~70
#   - Tier: Mid-to-high
#   - Perk: Iconic Eiffel Tower views
# - Hotel Marignan Champs-Élysées (Paris 8e)
#   - Capacity: Up to 100 for cocktails; 80 seated
#   - Tier: Luxury
#   - Perk: Chic, high-end service, central location
# - The Peninsula Paris (1er/Champs-Élysées)
#   - Capacity: Ballrooms up to 100 for sit-down dinners
#   - Tier: Luxury to Ultra-luxury
#   - Perk: World-class service, multiple luxe spaces, privacy
#
# Notes
# - All listed options can host ~100 guests in various setups (cocktail, seated, or privatised events).
# - Public price details aren’t always published; quotes are typically provided on request. I can handle the quote requests and availability checks for you.
#
# What I need from you to move forward (quick)
# - Date window/year you’re targeting (e.g., early June 2026 or early September 2026, or another window).
# - Budget range for the venue (ballpark per venue or total for venue + catering).
# - Preferred vibe/style: historic/chic, modern, iconic views, intimate/private, etc.
# - Do you want a ceremony included at the same site, or just a reception?
# - Catering style preference (in-house venue catering vs. external caterer) and any dietary needs.
# - Music plan: live jazz ensemble vs. DJ with jazz-influenced sets? Any must-have repertoires (e.g., standards, swing, modern jazz)?
# - Guest lodging: do you want me to suggest a small set of hotels near the venues, with group rates?
# - Transportation needs: private transfers from airport/hotel to venue?
#
# Next steps I can take once you confirm
# - Shortlist 3–5 top venues (based on vibe and price tier) and start requesting current availability and formal quotes for your target date.
# - Propose 1–2 live jazz acts or a DJ package with a jazz-forward set, and draft a provisional music plan (cocktail jazz, dinner background, party set).
# - Compile a preliminary wedding day timeline (ceremony, cocktail hour, reception, dinner, dancing) and recommended room layouts for each venue.
# - Suggest nearby hotels for guest blocks and outline group-rate options.
# - Create a clear budget breakdown (venue, catering, entertainment, decor, transport, accommodations) and a tentative timeline.
#
# Would you like me to:
# 1) Focus on a date window (e.g., early June 2026) and start checking availability/quotes for 3–4 top venues (Le Cabanon, Centre Monceau, Café de l’Homme, Hotel Marignan, Peninsula) and 1–2 live jazz options?
# 2) Or, share your preferred date/year and budget first, and I’ll tailor the shortlist accordingly?
#
# If you’re unsure about dates, I can propose two strong windows (e.g., early June 2026 and early September 2026) and move forward from there.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
