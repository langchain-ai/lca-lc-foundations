# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My knowledge cutoff is typically around **early to mid-2023**.
#
# This means:
# *   I have been trained on a vast amount of text and code data up until that point.
# *   I can provide information about events, discoveries, and developments that occurred **before** my knowledge cutoff.
# *   I do **not** have information about real-time current events, very recent news, or developments that have happened **after** that cutoff date.
#
# If you ask about something very recent, I might not have specific details, but I can often provide general background information or explain relevant concepts based on my training.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.95324475,
#    'raw_content': None},
#   {'url': 'https://ballotpedia.org/Daniel_Lurie',
#    'title': 'Daniel Lurie - Ballotpedia',
#    'content': 'Daniel Lurie is the Mayor of San Francisco in California. He assumed office on January 8, 2025. His current term ends on January 8, 2029.',
#    'score': 0.88799405,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.8755427,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.8488849,
#    'raw_content': None},
#   {'url': 'https://www.cbsnews.com/sanfrancisco/news/san-francisco-mayor-elect-daniel-lurie-claims-victory-outlines-vision-for-city/',
#    'title': 'San Francisco Mayor-elect Daniel Lurie claims victory, outlines ...',
#    'content': "San Francisco's Mayor-elect Daniel Lurie declared victory Friday morning as he addressed the city for the first time since incumbent Mayor London Breed",
#    'score': 0.8386933,
#    'raw_content': None}],
#  'response_time': 1.13,
#  'request_id': '8d769caf-fd43-4af1-9463-9aa3e65e118a'}

# %%
agent = create_agent(
    model=model,
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='61ea7314-e104-42e8-87f5-8da92d41f555'),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "current mayor of San Francisco"}'}, '__gemini_function_call_thought_signatures__': {'bf603add-37a4-4358-912a-f5025e361e92': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e3214-cbdd-70e1-a8d6-44a36e38fd15-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': 'bf603add-37a4-4358-912a-f5025e361e92', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 75, 'total_tokens': 122, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 56}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.sf.gov/profile--daniel-lurie", "title": "Daniel Lurie - SF.gov", "content": "Chair, and Mayor of San Francisco. Disaster Council · Office of the Mayor. Mayor Daniel Lurie sworn in as the City\'s 46th mayor on Jan 8. See recent news. Learn", "score": 0.98537, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Daniel_Lurie", "title": "Daniel Lurie - Wikipedia", "content": "Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco, serving since", "score": 0.98312, "raw_content": null}, {"url": "https://www.instagram.com/danielluriesf/", "title": "Daniel Lurie (@danielluriesf) • Instagram photos and videos", "content": "246K followers · 1 following · 1662 posts · @danielluriesf: “丹尼爾·羅偉 46th Mayor of the City and County of San Francisco”", "score": 0.97999, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "The current mayor is Democrat Daniel Lurie.", "score": 0.97562, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=cu9Cc8TEGog", "title": "SF Mayor Daniel Lurie delivers 1st State of the City address - YouTube", "content": "San Francisco Mayor Daniel Lurie will deliver his first State of the City address, highlighting that the city is \\"on the rise\\" and that", "score": 0.96707, "raw_content": null}], "response_time": 1.55, "request_id": "6bfa6897-cbc8-4bc0-9447-047532ef5917"}', name='web_search', id='f8a5f4b0-ad9d-41cf-be62-c4f8e2a91e5a', tool_call_id='bf603add-37a4-4358-912a-f5025e361e92'),
#  AIMessage(content=[{'type': 'text', 'text': 'The current mayor of San Francisco is Daniel Lurie.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e3214-ddab-7973-8120-03dee5ef90e1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 615, 'output_tokens': 68, 'total_tokens': 683, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 57}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
