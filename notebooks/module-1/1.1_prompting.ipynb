# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
)

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun question!
#
# The Moon doesn't have a capital because it's not a country, state, or political entity. It's a celestial body with no government, no cities, and no permanent human population (yet!).
#
# If humans were to colonize the Moon in the future, they might establish settlements and eventually designate one as a "capital" for their lunar operations, but for now, it's just a big, beautiful rock in space.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the Moon is **Lunaris Prime**.
#
# Nestled within the vast, ancient impact basin of **Clavius**, Lunaris Prime isn't a single monolithic city but a sprawling, multi-tiered metropolis. Its core is built deep within the crater's subsidiary formations and an extensive network of naturally occurring lava tubes, providing unparalleled shielding from radiation and micrometeorites.
#
# **Appearance & Architecture:**
#
# *   **The Sky-Domes:** On the surface, visible from orbit, are Lunaris Prime's iconic "Sky-Domes." These are massive, multi-layered geodesic structures, often built into the crater rim itself, housing public parks, observation decks, and the administrative towers of the Lunar Assembly. Their heavily reinforced, transparent upper layers offer breathtaking, panoramic views of the lunar regolith, the distant Earth, and the star-dusted void.
# *   **Terraced Levels:** Below the Sky-Domes, terraced into the crater walls, are residential districts and bustling commercial hubs. These areas are protected by meters of regolith and advanced energy shields, with "sun-pipes" channeling filtered sunlight down into the living spaces, creating a semblance of terrestrial daylight.
# *   **The Under-City (Subterranean):** The true heart of Lunaris Prime lies deep beneath the surface. An intricate network of excavated caverns and repurposed lava tubes houses the essential life-support systems, heavy industry, expansive hydroponic farms, cutting-edge scientific research facilities, and critical infrastructure. This is where the air is thickest, the gravity most subtly manipulated, and the hum of innovation is constant.
#
# **Lifestyle & Culture:**
#
# Lunaris Prime is a beacon of international cooperation and human ingenuity. Its low-gravity environment has fostered unique forms of architecture, art, and even sports. Residents, known as "Lunari," are a diverse blend of scientists, engineers, artists, and pioneers from across Earth. Public spaces often feature "Earth-Gaze Arcades," offering stunning, real-time views of the home planet, fostering a deep connection to humanity's origins.
#
# As the administrative and economic capital, Lunaris Prime is the primary nexus for deep-space missions, a crucial research outpost, and the central processing hub for the Moon's vast resources, making it a pivotal stepping stone for humanity's expansion into the cosmos.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunovia

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
