# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not have a capital.\n\nIt\'s not a country or a political entity, and it doesn\'t have a government or permanent human settlements with cities.\n\nHowever, if humans were to establish permanent settlements and a governing body there, a popular and historically significant candidate for a "capital" might be **Tranquility Base**, the landing site of Apollo 11. But for now, it\'s just a celestial body!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e31b0-65d0-72f0-aa8e-5fd0a3203898-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 812, 'total_tokens': 822, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 721}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's not a country or a political entity, and it doesn't have a government or permanent human settlements with cities.
#
# However, if humans were to establish permanent settlements and a governing body there, a popular and historically significant candidate for a "capital" might be **Tranquility Base**, the landing site of Apollo 11. But for now, it's just a celestial body!

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's Earth's natural satellite, not a country or a sovereign territory with a government or cities that would designate a capital. While there have been temporary human missions to the Moon, and future lunar bases are planned, no permanent, self-governing human settlement exists there yet that would establish a capital city.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way that Earth countries do. It's not a country, and there are no permanent settlements or governments there.
#
# So, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='d8d61e38-81ae-48be-9c92-46af42ddeb28'),
#               AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city because it\'s not a country or a populated planet. It\'s a natural satellite.\n\nHowever, if we were to imagine a "capital" based on human activity, the **Tranquility Base** on the Sea of Tranquility would be the most fitting. This is where the Apollo 11 mission landed in 1969, and it\'s where Neil Armstrong and Buzz Aldrin took humanity\'s first steps on the Moon. It\'s a historically significant location!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e31b2-ac6e-7d83-93b9-aaeeee6817ec-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 117, 'total_tokens': 127, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city because it's not a country or a populated planet. It's a natural satellite.
#
# However, if we were to imagine a "capital" based on human activity, the **Tranquility Base** on the Sea of Tranquility would be the most fitting. This is where the Apollo 11 mission landed in 1969, and it's where Neil Armstrong and Buzz Aldrin took humanity's first steps on the Moon. It's a historically significant location!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='d54a7ea5-1a58-4b7a-b1ac-3a9c7cc452b4'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='8d80c1e8-88e5-4e97-b9c9-4acc939f0a1c', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='e4a662e0-b7b5-40a5-b897-3c6326c55351'),
#               AIMessage(content="Luna City is a fictional city often depicted as the capital of the Moon in science fiction. It's usually portrayed as a bustling metropolis, a hub of lunar activity, and a center of government and commerce.\n\nHere are some common elements and ideas associated with Luna City in fiction:\n\n**Location and Structure:**\n\n*   **Underground or Dome-Covered:** Due to the Moon's lack of atmosphere and harsh radiation, Luna City is often depicted as being built underground, within lava tubes, or under protective domes. This provides a stable environment for life.\n*   **Modular and Expandable:** As lunar colonization grows, cities are often imagined as being built in modular sections that can be expanded as needed.\n*   **Verticality:** To maximize space and create distinct districts, Luna City might have a strong vertical element, with different levels dedicated to residential, commercial, industrial, and recreational purposes.\n\n**Society and Governance:**\n\n*   **Independent Lunar Government:** Luna City typically serves as the seat of an independent lunar government, separate from Earth's nations. This government might be a republic, a federation, or even something more unique.\n*   **Diverse Population:** While initially founded by humans, Luna City could evolve to include diverse populations, perhaps with different factions, corporate entities, or even alien species if the story allows.\n*   **Unique Culture:** Lunar society would likely develop its own distinct culture, influenced by the challenges and opportunities of living on another celestial body. This could include new art forms, social norms, and philosophies.\n\n**Economy and Industry:**\n\n*   **Resource Extraction:** The Moon is rich in resources like Helium-3 (a potential fusion fuel), rare earth elements, and water ice. Luna City would likely be the center for mining and processing these resources.\n*   **Scientific Research:** Being on the Moon offers unparalleled opportunities for astronomical observation and scientific research. Luna City would house advanced observatories and research facilities.\n*   **Spaceport and Trade Hub:** It would likely be a major spaceport, facilitating trade and travel between the Moon, Earth, and other potential off-world settlements.\n*   **Tourism:** As humanity expands, lunar tourism could become a significant industry, with Luna City being a prime destination.\n\n**Challenges and Conflicts:**\n\n*   **Resource Scarcity:** Despite lunar resources, managing them efficiently and ensuring equitable distribution would be a constant challenge.\n*   **Environmental Control:** Maintaining a habitable environment within the city would require constant vigilance and advanced technology.\n*   **Political Tensions:** Conflicts could arise between different factions within Luna City, or between the lunar government and Earth-based powers over resources, independence, or ideology.\n*   **Existential Threats:** The Moon is a harsh environment, and potential threats like meteoroid impacts or system failures would always be a concern.\n\n**In essence, Luna City is a powerful symbol of humanity's ambition to explore, colonize, and thrive beyond Earth. It represents a potential future where humanity has established a permanent presence among the stars.**\n\nSince it's a fictional concept, its exact appearance and characteristics can vary greatly depending on the author, book, movie, or game it appears in. Some popular examples of lunar cities in science fiction include:\n\n*   **Trantor** (from Isaac Asimov's *Foundation* series, though it's an ecumenopolis on Terra, the concept of a capital city on another world is similar)\n*   **Lunar City** (from various sci-fi works, often a generic term)\n*   **Selenopolis** (a name that has appeared in some contexts)\n\nDo you have a particular story in mind where you encountered Luna City? Knowing that might help me give you more specific details!", additional_kwargs={}, ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, the shining beacon of human achievement and the capital of the Moon, is a testament to our species' boundless ambition. While it's still a vision of the future, the concept of Luna City is rich with detail and potential, drawing inspiration from science fiction and the practicalities of lunar habitation.
#
# Here's a comprehensive look at what Luna City, the capital of the Moon, might be:
#
# **Location and Geography:**
#
# *   **Strategic Placement:** Luna City would likely be situated in a location offering the most advantageous conditions for long-term survival and development. Prime candidates include:
#     *   **Lunar Poles (North or South):** These regions offer the tantalizing prospect of "peaks of eternal light" and "craters of eternal darkness." The peaks would provide consistent solar power, while the dark craters could be ideal for specialized research (astronomy, low-temperature physics) and even for storing volatile materials.
#     *   **Mare Tranquillitatis (Sea of Tranquility):** The historical landing site of Apollo 11, this vast, relatively flat plain offers accessibility and potential for expansion.
#     *   **Lava Tubes:** These natural subterranean tunnels offer excellent shielding from radiation and micrometeoroids, providing a naturally protected environment for construction.
# *   **Underground vs. Surface:** A significant portion of Luna City would likely be **underground or within lava tubes** to protect inhabitants from the harsh lunar environment:
#     *   **Radiation Shielding:** The Moon lacks a significant atmosphere or magnetic field, making it vulnerable to solar and cosmic radiation. Underground structures offer natural protection.
#     *   **Micrometeoroid Protection:** The constant bombardment of tiny space rocks is a serious hazard. Buried habitats provide a robust defense.
#     *   **Temperature Regulation:** Surface temperatures on the Moon fluctuate wildly. Underground environments offer more stable temperatures.
# *   **Surface Domes and Structures:** While much is underground, surface elements would also exist, likely encased in robust, transparent domes or made of reinforced lunar regolith-based materials. These would offer:
#     *   **Views of Earth and Space:** A crucial psychological element for inhabitants.
#     *   **Controlled Environments:** For agriculture, recreation, and specialized industries.
#     *   **Access Points:** For transportation and external operations.
#
# **Infrastructure and Systems:**
#
# *   **Power Generation:**
#     *   **Solar Power:** Dominant, especially at the poles with "peaks of eternal light." Large solar farms would be essential.
#     *   **Nuclear Power:** Likely a backup or primary source for areas with less consistent sunlight, or for high-demand industrial zones.
#     *   **Geothermal (potential):** While the Moon is not tectonically active like Earth, there might be residual internal heat in certain areas that could be harnessed.
# *   **Water and Life Support:**
#     *   **Water Ice Mining:** The discovery of water ice in shadowed craters at the poles is a game-changer. This ice would be crucial for drinking water, oxygen production (via electrolysis), and rocket propellant.
#     *   **Closed-Loop Systems:** Advanced recycling systems for air, water, and waste would be paramount to minimize reliance on Earth.
#     *   **Atmosphere Generation:** Creating and maintaining a breathable atmosphere within habitats would be a complex engineering feat.
# *   **Transportation:**
#     *   **Internal:** Maglev trains, electric vehicles, and moving walkways would connect different sectors of the city.
#     *   **External:** Pressurized rovers, specialized lunar craft for traversing the surface, and potentially even lunar "trams" or cable cars connecting key surface locations.
#     *   **Spaceport:** A major hub for interplanetary travel, cargo, and personnel transfers.
# *   **Communication:**
#     *   **High-Speed Networks:** Essential for internal communication and for maintaining a constant link with Earth.
#     *   **Deep Space Network Integration:** Luna City would likely be a key node in Earth's deep space communication infrastructure.
# *   **Waste Management and Recycling:**
#     *   **Advanced Recycling:** Every resource would be precious. Comprehensive recycling of waste into usable materials or energy would be vital.
#     *   **Waste-to-Energy:** Utilizing waste for power generation.
#
# **Society and Governance:**
#
# *   **Population:** Initially, a small, highly skilled workforce, growing to a more diverse population over time. This would include scientists, engineers, miners, agriculturalists, service workers, and eventually families.
# *   **Governance:** Likely a multi-faceted approach:
#     *   **International Oversight:** Given the likely collaborative nature of lunar settlement, an international governing body would be probable, overseeing resource allocation, safety standards, and dispute resolution.
#     *   **Local Administration:** A city council or similar body to manage day-to-day affairs, public services, and local laws.
#     *   **Corporate Influence:** Companies involved in resource extraction, research, and development would likely play a significant role.
# *   **Economy:** Driven by:
#     *   **Resource Extraction:** Helium-3 for fusion power, rare earth elements, and other valuable minerals.
#     *   **Scientific Research:** Astronomy, physics, biology, and materials science conducted in the unique lunar environment.
#     *   **Tourism:** As the city develops, it could become a premier destination for adventurous tourists.
#     *   **Manufacturing:** Utilizing lunar resources for in-situ manufacturing of goods and spare parts.
#     *   **Space Industry Hub:** A base for further exploration and colonization of the solar system.
# *   **Culture and Lifestyle:**
#     *   **Adaptation to Low Gravity:** A significant aspect of daily life. Specialized sports, exercise regimes, and even architectural designs would cater to 1/6th Earth's gravity.
#     *   **Sense of Community:** The shared experience of living in such a unique and challenging environment would foster a strong sense of camaraderie.
#     *   **Connection to Earth:** While independent, a deep cultural and emotional connection to Earth would persist.
#     *   **Art and Entertainment:** Likely reflecting the unique environment, with art inspired by the lunar landscape, Earthrise, and the cosmos.
#     *   **Education and Research:** A strong emphasis on STEM fields and continuous learning.
#
# **Challenges and Considerations:**
#
# *   **Cost of Construction and Maintenance:** Building and sustaining a city on the Moon would be incredibly expensive.
# *   **Psychological Impact:** The isolation, confinement, and lack of natural Earth-like environments could pose psychological challenges for residents.
# *   **Health Risks:** Long-term effects of low gravity and radiation exposure are still being studied.
# *   **Resource Scarcity:** While resources exist, their extraction and processing are complex and energy-intensive.
# *   **Ethical and Legal Frameworks:** Establishing clear laws and ethical guidelines for lunar settlement, resource ownership, and potential extraterrestrial life is crucial.
# *   **Dependence on Earth:** Initial reliance on Earth for supplies and expertise would be significant, with a long-term goal of self-sufficiency.
#
# **Vision of Luna City:**
#
# Imagine a city of gleaming domes on the surface, connected by subterranean tunnels to vast underground complexes. Parks with carefully cultivated hydroponic gardens would offer splashes of green under artificial light. Observatories would pierce the inky blackness of space, capturing the universe's secrets. The constant hum of life support systems would be the backdrop to a society driven by innovation, exploration, and a shared dream of a multi-planetary future.
#
# Luna City is more than just a capital; it's a symbol of humanity's reach, our ability to overcome immense challenges, and our enduring quest to explore the unknown. It represents a future where the Earth is not our only home, but a cherished jewel in a vast cosmic neighborhood.
