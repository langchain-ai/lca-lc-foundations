# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(
    model = "gpt-5-nano"
)

question = HumanMessage(content = "Hello, my name is Koushal S Modi, and my favorite colour is yellow.")

response = agent.invoke({
    "messages": [question]
})

from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello, my name is Koushal S Modi, and my favorite colour is yellow.', additional_kwargs={}, response_metadata={}, id='75a92a43-0945-4dcc-abc8-e689ece065a7'),
# ...

# %%
question = HumanMessage(content = "What's my favorite colour? ")
response = agent.invoke({
    "messages": [question]
})

from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favorite colour? ", additional_kwargs={}, response_metadata={}, id='adb4837f-ee66-47f0-a76e-7441190a8696'),
# ...

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver

new_agent = create_agent(
    model = "gpt-5-nano",
    checkpointer = InMemorySaver(),
)

question = HumanMessage(content = "Hello, my name is Koushal S Modi, and my favorite colour is yellow.")

config = {"configurable": {"thread_id": "1"}}

response = new_agent.invoke(
    {"messages": [question]},
    config
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello, my name is Koushal S Modi, and my favorite colour is yellow.', additional_kwargs={}, response_metadata={}, id='8253a125-4a5b-4284-8082-f3e5f1c87bf8'),
# ...

# %%
question = HumanMessage(content = "What's my favorite colour? ")
response = new_agent.invoke(
    {"messages": [question]},
    config
)

from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello, my name is Koushal S Modi, and my favorite colour is yellow.', additional_kwargs={}, response_metadata={}, id='8253a125-4a5b-4284-8082-f3e5f1c87bf8'),
# ...
