# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital. International treaties govern activities there, not a national capital. If you’re after a fictional idea, tell me the vibe and I can suggest a capital concept and name.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 576, 'prompt_tokens': 13, 'total_tokens': 589, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpJ2tGoPHcFzqcOATD0u9KxAOL6We', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b424e-1f3e-7bd0-b141-b2daf8cab9d5-0', usage_metadata={'input_tokens': 13, 'output_tokens': 576, 'total_tokens': 589, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. International treaties govern activities there, not a national capital. If you’re after a fictional idea, tell me the vibe and I can suggest a capital concept and name.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-CpJ2tGoPHcFzqcOATD0u9KxAOL6We',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 576,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 589}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or population, so it has no capital. If you’re thinking of a fictional setting, you’d need to pick a city name for that story.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite - a celestial body with no permanent population or government.
#
# If you're asking about lunar geography, notable locations include the Sea of Tranquility (where Apollo 11 landed) or the lunar south pole (a focus for future exploration). But none of these would be considered a "capital" in any official sense.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question!
#
# The Moon doesn't have a capital city because it's not a country and has no government or permanent human population to establish one.
#
# If humans ever extensively colonize the Moon and establish a unified government, they might create one! Some science fiction suggests names like "New Lunar City" or even "Tranquility Base" (after the Apollo 11 landing site) as a central hub.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='a66bdfab-b396-42f7-ba99-d617c037f52e'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital.\n\nIf you’re thinking in fiction or future scenarios, people sometimes invent names for a lunar capital, e.g. Lunapolis, Luna City, Selene, or Artemis Prime. Want me to brainstorm some options based on the vibe you want (futuristic, dystopian, utopian, etc.)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 927, 'prompt_tokens': 13, 'total_tokens': 940, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpJ4mnoTXCn8LMS3IQYqsFfyNOXOJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b424f-ea40-7ae0-9100-59dcddc7724c-0', usage_metadata={'input_tokens': 13, 'output_tokens': 927, 'total_tokens': 940, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital.
#
# If you’re thinking in fiction or future scenarios, people sometimes invent names for a lunar capital, e.g. Lunapolis, Luna City, Selene, or Artemis Prime. Want me to brainstorm some options based on the vibe you want (futuristic, dystopian, utopian, etc.)?

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='56ba35f0-c5b8-401c-87cb-32d66fcb186b'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='74f9d4f0-c03a-4760-8b36-d2bd757c2190'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='3fe801b0-ea49-499f-9d5a-88e75e151a02'),
#               AIMessage(content="You're right—the Moon isn’t a country and has no capital in real life. If you’re asking about a fictional setting, here’s a ready-to-use concept for Luna City you can drop into a story or world-building game.\n\nOverview\n- Name: Luna City, the political and cultural heart of the Luna Confederation (a lunar federation formed by Earth nations and independent settlements).\n- Location: A sheltered basin on the near side of the Moon, near a basalt plains region with good line-of-sight to Earth for comms; protected by a crater rim and insulated from micro-meteoroids.\n- Vibe: A sleek, functional megacity built into and atop regolith, with a blend of domes, hardened tunnels, and 3D-printed structures. Neon-lit nights, solar-powered daylight, and a hardworking, optimistic culture.\n\nGovernment and institutions\n- Ruling body: The City Council of Luna City, elected by residents (humans and long-term lunar inhabitants) with a rotating chairperson called the Governor.\n- Key agencies: Lunar Operations Authority (infrastructure and resource management), Habitat and Health Directorate (life support, medical care, and housing), and the Research Arc (science and innovation hub).\n- Legal framework: Intermittent Earth-Luna accords govern mining rights, water ice extraction, and transit to Earth; local bylaws handle daily life, education, and emergency response.\n\nPopulation and culture\n- Population size: Several hundred thousand to a few million residents over time, including long-term settlers, researchers, engineers, and support staff.\n- Daily life: A mix of shift work (to match the 14.75-day lunar cycle), with leisure and culture concentrated around central plazas, dome parks, and communal hydroponic farms.\n- Languages and identity: A multilingual society with English as a common lingua franca, plus local dialects and technical jargon; a shared lunar identity develops around resilience, exploration, and the pursuit of science.\n\nEconomy and infrastructure\n- Main sectors: \n  - Resource and materials: mining and processing of basalt for construction, ice harvesting for water and fuel.\n  - Research and development: biotech, materials science, robotics, and space medicine.\n  - Tourism and culture: lunar museums, observatories, zero-g experiences in controlled habitats.\n- Energy and water: Solar arrays supplementing a compact, closed-loop life-support system; water ice from poles or shadowed craters processed into drinking water and oxygen.\n- Housing and habitats: Regolith-based domes and 3D-printed interiors; radiation shielding via thick walls and regolith overburden; modular apartments with communal farms and shared workshops.\n- Transportation: \n  - In-city transit: electric rovers and magnetic rail shuttles in protected tunnels.\n  - Link to Earth: regular shuttles and a spaceport hub for cargo and passengers; a conceptual lunar transit elevator could be in planning.\n\nTechnology and science\n- Life support: Closed-loop air and water systems, hydroponic or aeroponic farms for food, waste recycling.\n- Construction: On-site 3D printing from lunar regolith; autonomous drones and repair bots.\n- Health and safety: Radiation monitoring, dust management, emergency shelter networks, and mental-health support programs to counter isolation.\n\nChallenges and conflicts (story hooks)\n- Resource politics: Who controls water ice or mineral rights? Conflicts between Earth-based corporations and independent lunar settlements.\n- Environmental hazards: Dust storms, regolith erosion, solar storms, and long lunar nights impacting energy and life-support systems.\n- Social dynamics: Integration of diverse cultures; governance tensions between rapid innovation and civilian rights.\n- Mystery or thriller threads: A missing water-ice shipment, a data breach at the Research Arc, or a political scandal around resettlement plans.\n\nVisual and mood notes\n- Architecture: Geodesic domes, glassy atria, reinforced tu ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional capital for the Moon in many sci-fi settings. Here’s a thorough profile you can use for world-building, a novel, game, or screenplay. It’s designed to feel plausible within a hard-SciFi frame, while remaining flexible for different tones (grimdark, utopian, corporate-dystopian, etc.).
#
# Overview
# - What it is: The political, cultural, and logistical heart of human activity on the Moon. Seat of the Lunar Coalition Government, centerpiece for science, industry, education, and diplomacy between Earth and lunar settlements.
# - Location (in-universe): On the near side of the Moon, near the equator, positioned to maximize solar power generation and ease of transport to Earth. Built around a prominent impact basin rim with access to a harbor of flat plains and permanent shadow pockets for water ice.
# - Size and feel: A megacity-arcology complex sprawled across several linked domed districts and subterranean layers. The surface city is a mosaic of glass-and-regolith domes, orbital rails, and sheltered streets. It blends monumental government architecture with dense residential and industrial layers, all tuned for radiation shielding, dust control, and thermal stability.
#
# Geography and Layout
# - Core geography: A circular or crescent-shaped urban footprint layered into: surface districts (polished habitat domes and solar farms), a mid-layer “arcology spine” with transit lines and vertical neighborhoods, and an extensive subterranean base for life support, manufacturing, and storage.
# - Districts (typical setup):
#   - Government District: The Spire and surrounding pavilions where the Lunar Coalition Parliament, Prime Administrator’s Office, and the Archives reside.
#   - Administrative-Civic Quarter: Courts, ministries, citizen services, and the Lunar Day Market.
#   - Residential Arcology Ring: Tiered living blocks, hydroponic farms, schools, clinics, and cultural centers.
#   - Research and Education Quarter: Universities, think tanks, laboratories, and the Observatory/Space Telescope Complex.
#   - Industrial and Logistics Quarter: Material processing, 3D printing hubs, mining command centers, and energy farms.
#   - Port and Transit Hub: The Astraport spaceport, lunar elevator/rail access, and interplanetary comms hub.
# - Architecture: A mix of radiation-shielded colonies with transparent public spaces. Surfaces use regolith shielding, integrated hydroponic canopies, and energy-efficient lighting. Some districts feature anti-dust windbreaks and underground pedestrian networks to cope with the lunar day/night cycle.
#
# History and Timeline (compact)
# - Founding: First permanent settlement established in response to Earth’s growing need for a lunar outpost, chosen for proximity to water ice in permanently shadowed regions and mineral riches in nearby basins.
# - Rise to capital: As settlements expanded, Luna City grew into the political and economic hub. A landmark treaty with Earth established a semi-autonomous governance framework under the Lunar Coalition.
# - Key milestones:
#   - Initial terraforming meets lunar engineering milestones (airlocks, pressurized tunnels, robust life-support loops).
#   - Discovery and exploitation of near-surface water ice leading to self-sustaining operations and brine extraction.
#   - The Spire completed and designated as the symbolic heart of lunar governance.
#   - A period of social and technological innovation spurred by proximity to Earth and the abundance of solar energy.
#
# Government and Society
# - Governance: A semi-autonomous polity known as the Lunar Coalition Government. It operates with a Parliamentary-Cederal structure and a Chief Administrator who oversees executive functions. The Parliament (Lunar Assembly) sits in the Government District, with representatives elected from districts or appointed by lunar settlements.
# - Legal system: A hybrid civil-law system adapted to lunar conditions, with special provisions for space-related commerce, resource rights (e.g., water and helium-3), and environmental protection in vacuum-based habitats.
# - Citizenship: Citizens include lifelong lunar residents, Earth-born settlers who attained lunar citizenship, and long-term workers who obtain residency. There is a strong emphasis on education, public service, and scientific contribution.
# - Security and defense: The Moon Police and a Guard Corps operate with exo-suits and armored rovers. A Joint Space Defense Command coordinates with Earth-based forces for major threats. Private security and corporate guards are common in the industrial districts.
# - Culture and society: A cosmopolitan culture blending Earth languages, lunar survival know-how, and a distinct lunar-urban identity. Public life centers around the Lunar Day Market, observatories, museums, and open-air plazas designed to accommodate the 14-Earth-day light cycle.
#
# Economy and Infrastructure
# - Core industries:
#   - Resource extraction and processing (ice mining, regolith processing, basalt glass production).
#   - Solar energy generation and energy storage.
#   - High-precision manufacturing (3D printing, microfabrication, optical components).
#   - Life-support systems, hydroponics, and food production.
#   - Research and development in materials science, robotics, AI, and space medicine.
# - Currency and trade: A lunar-credits system backed by Earth-established banks. Trade flows with Earth and other colonies include water, metals, propellants, rare isotopes, and manufactured goods.
# - Infrastructure highlights:
#   - Solar farms and thermal management systems integrated into the arcology shells.
#   - Subterranean life-support corridors with air, water, and waste recycling loops.
#   - A hybrid transit network: pressurized rovers, maglev-like surface rails, and a vertical transit spine in the Arcology that links surface districts to underground hubs.
#   - The Astraport: A major spaceport that serves freight, civilian travel, and shuttle traffic to Earth orbit and back.
# - Water and energy security: Water ice in shadowed craters is harvested and refined; current lunar settlements rely heavily on solar power, supplemented by compact nuclear or fusion micro-reactors in some districts.
#
# Technology and Science
# - Life support: Closed-loop ecology systems with hydroponics, algae-based air regeneration, and compact bioreactors to recycle waste into usable resources.
# - Housing: Radiation shielding integrated into dome structures, with smart materials and reconfigurable interiors to adapt to the long lunar day-night cycle.
# - Transportation:
#   - Surface rovers and pressurized transit modules for short trips.
#   - Lunar elevators or elevated transit spines (magnetic or mechanical) in the urban core.
#   - The Astraport for interplanetary travel with secure docking bays.
# - Communications: High-bandwidth quantum or relay networks connecting Luna City to Earth and other lunar settlements, with redundant lines to ensure continuity during solar disruption.
# - Science hubs: A prominent Observatory/Space Telescope complex, a Lunar Innovation Lab, and multiple research stations focused on astrochemistry, materials science, and life-support research.
#
# Education and Culture
# - Education system: Public schools for K-12, a Lunar University with STEM-focused faculties, medical and life-support training programs, and vocational institutes for mining, manufacturing, and environmental management.
# - Cultural life: A blend of Earth-origin cultures fused with lunar-adapted traditions. Public theaters, museums, and festival spaces celebrate both Earth heritage and lunar discoveries. The lunar night markets and safe outdoor plazas host communal events during the two-week day/night cycle.
# - Language: Common trade language (Earth-based lingua franca) plus local dialects and signs designed for clear cross-district communication. Teaching of Martian or Earth dialects for interplanetary diplomacy is common in higher education.
#
# Notable Locations and Landmarks
# - The Spire: The central governance tower—a symbol of lunar sovereignty, with observation decks and a public archive.
# - Archive Plateau: A vast repository housing historical documents, scientific data, and cultural artifacts from lunar settlements and Earth diplomacy.
# - The Crescent Market: A multi-level public market and social hub for commerce, culture, and casual gatherings during the daylight phase.
# - The Observatory Ring: A cluster of telescopes and instruments offering planetary, solar, and deep-space observation; a place of study and public outreach.
# - The Hydroponic Gardens: A district-scale farm that provides fresh produce to the city while functioning as a public green space and research site.
# - Astraport and Transport Spine: The main interplanetary port with surface-to-orbit transport lines, freight facilities, and passenger terminals.
#
# Living on Luna City
# - Daily life: Residents experience the long lunar day as a rhythm—work and social activities occur during daylight with cooling and maintenance phases during the long night. Weather is not atmospheric but thermal and radiation-based, so interiors are climate-controlled and dust is minimized by airlocks and chambered corridors.
# - Housing: People live in vertically integrated arcologies or semi-private domes with shared hydroponics and community spaces. Families might occupy modular units that can be reorganized as needed.
# - Healthcare: Advanced telemedicine and on-site clinics that specialize in radiation exposure management, zero-gravity physiology, and emergency care for spaceflight.
#
# Possible Variants and Tones
# - Utopian Luna City: An idealized, highly automated city with near-perfect life-support systems, minimal pollution, transparent governance, and a vibrant civil society.
# - Corporate-dystopia Luna City: A city run by mega-corporations, where citizens are tracked, jobs are precarious, and city planning serves profit as much as public good.
# - Frontier Luna City: A younger, less stable city with ongoing expansion, more informal settlements, and substantial plasticity in governance as new districts are built, torn down, or rebuilt.
# - Scientific utopia: A hub for space research that prioritizes open science, cross-cultural collaboration, and ambitious astronomical projects.
#
# Story and Scene Seeds (if you’re writing fiction)
# - A political crisis: A controversial policy on water rights sparks protests in the Crescent Market, while the Spire debates a security crackdown.
# - A discovery mission: A new underground water reservoir is found beneath a transit tunnel, changing energy and life-support planning.
# - Diplomacy arc: Earth negotiates a new treaty with lunar settlements; Luna City hosts ambassadors, public forums, and a joint science council.
# - A personal tale: A young planetary engineer learns to navigate the long lunar night while repairing a critical life-support system during a city-wide blackout.
#
# If you want, I can tailor Luna City to your exact setting—specify tone (hard sci-fi, space opera, cyberpunk, etc.), era (early colonization vs. mature lunar civilization), or the critical backstory (Earth governance model, corporate involvement, alien contact). I can also draft a map sketch, a day-in-the-life scene, or a political-historical timeline to fit your project.

# %% [markdown]
# ## Structured Output

# %%
from pydantic import BaseModel

class ResponseFormat(BaseModel):
    name:str
    location:str
    vibe: str
    economy:str
    
system_prompt = f""" 
You are a fictional writer and based on user's request you need to come up with a fictional city.
Please ensure to structure the output in the following way:
Name: The name of the city based on user's request.
Location: Where the fictional city is located.
Vibe: Describe the city in 2-3 words.
Economy: List in a few words the industries present in the city
"""

question = HumanMessage(content = "What's the capital of the moon?")

# %%
agent = create_agent(
    model="gpt-5-nano",
    system_prompt = system_prompt,
    response_format = ResponseFormat
)

response = agent.invoke({"messages": [question]})
print(response['structured_response'])
# Out:
# name='Selene Capital' location='Lunar south pole, Shackleton Crater rim' vibe='Luminous lunar citadel' economy='Helium-3 mining, solar energy, scientific research, lunar tourism'
